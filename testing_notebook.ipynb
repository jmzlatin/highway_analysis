# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/jordanzlatin/Library/Mobile Documents/com~apple~CloudDocs/project_for_zach/ניתוח תאונות דרכים כביש 16 מעודכן עד סוף אוק 2024 .xlsx")

# Drop the Unnamed columns from the excel file 
df.drop(columns=[col for col in df.columns if 'Unnamed' in col], inplace=True)

#rename the columns to english
df.rename(columns={
    'ID': 'id',
    'Timestamp': 'timestamp',
    'תאריך': 'date',
    'חודש': 'month',
    'חציון': 'half_year',
    'חציון number': 'half_year_number',
    'month number': 'month_number',
    'שעה מדויק': 'exact_hour',
    'שעה עגולה': 'rounded_hour',
    'מיקום': 'location',
    'אבני ק״מ': 'km_stones',
    'כיוון': 'direction',
    'מספר מנהרה או מחלף': 'tunnel_or_interchange_number',
    'נ.צ.': 'coordinates',
    'סוג תאונה': 'accident_type',
    'סוג רכב א (המסתמן כאשם)': 'vehicle_type_a',
    'סוג רכב ב\'': 'vehicle_type_b',
    'סוג רכב ג': 'vehicle_type_c',
    'סוג רכב ד\'': 'vehicle_type_d',
    'סוג רכב ה\'': 'vehicle_type_e',
    'חומרת תאונה': 'accident_severity',
    'הרוגים': 'fatalities',
    'פצועים קשה': 'serious_injuries',
    'פצועים קל': 'minor_injuries',
    'סהכ נפגעים': 'total_injuries',
    'מהירות נסיעה (בכיוון נסיעת רכב א)': 'travel_speed',
    'מצב מיסעה': 'road_condition',
    'סוג דרך': 'road_type',
    'מזג אויר': 'weather',
    'מצב תאורה': 'lighting_condition',
    'מצב תאורה + חומרת תאונה': 'lighting_condition_accident_severity',
    'סוג תאונה + חומרת תאונה': 'accident_type_severity',
    'סוג תאונה + חומרת תאונה + סהכ נפגעים': 'accident_type_severity_total_injuries',
    'מס אירווע בגיב ': 'event_number'
}, inplace=True)

# %%
df
# Out:
#       id           timestamp       date    month     half_year  \
# 0      1 2022-09-02 15:42:00 2022-09-02  Sept-22  חציון ב 2022
# 1      2 2022-09-05 21:10:00 2022-09-05  Sept-22  חציון ב 2022
# 2      3 2022-09-08 15:21:00 2022-09-08  Sept-22  חציון ב 2022
# 3      4 2022-09-09 09:50:00 2022-09-09  Sept-22  חציון ב 2022
# 4      5 2022-09-12 17:36:00 2022-09-12  Sept-22  חציון ב 2022
# ..   ...                 ...        ...      ...           ...
# 334  335 2024-10-22 15:30:00 2024-10-22   Oct-24  חציון ב 2024
# 335  336 2024-10-29 18:33:00 2024-10-29   Oct-24  חציון ב 2024
# 336  337 2024-10-30 16:25:00 2024-10-30   Oct-24  חציון ב 2024
# 337  338 2024-10-31 04:25:00 2024-10-31   Oct-24  חציון ב 2024
# 338  339 2024-11-01 01:17:00 2024-11-01   Nov-24  חציון ב 2024
#
#      half_year_number  month_number exact_hour rounded_hour  \
# 0                   1             1   15:42:00        16:00
# 1                   1             1   21:10:00        21:00
# 2                   1             1   15:21:00        15:00
# 3                   1             1   09:50:00        10:00
# 4                   1             1   17:36:00        18:00
# ..                ...           ...        ...          ...
# 334                 5            26   15:30:00        16:00
# 335                 5            26   18:33:00        19:00
# 336                 5            26   16:25:00        16:00
# 337                 5            26   04:25:00        04:00
# 338                 5            27   01:17:00        01:00
#
#                          location  ...  total_injuries travel_speed  \
# 0                 מנהרה T2 מעבר 3  ...               0         80.0
# 1                        מנהרה T2  ...               0         80.0
# 2                        מנהרה T3  ...               0         80.0
# 3                        מנהרה T3  ...               1         80.0
# 4                      יציאה מ T3  ...               0         30.0
# ..                            ...  ...             ...          ...
# 334               מנהרה T2 מעבר1   ...               0         80.0
# 335     מנהרה T2 מעבר 2 נתיב שמאל  ...               0         80.0
# 336     מנהרה T2 מעבר 2 נתיב ימין  ...               0         80.0
# 337              מנהרה T3 מעבר 9   ...               0         80.0
# 338  יציאה ממנהרה T12, מחלף רבידה  ...               0         50.0
#
#     road_condition road_type weather lighting_condition  \
# 0              יבש     מנהרה    בהיר        תאורת מנהרה
# 1              יבש     מנהרה    בהיר        תאורת מנהרה
# 2              יבש     מנהרה    בהיר        תאורת מנהרה
# 3              יבש     מנהרה    בהיר        תאורת מנהרה
# 4              יבש      צומת    בהיר            אור יום
# ..             ...       ...     ...                ...
# 334            יבש     מנהרה    בהיר        תאורת מנהרה
# 335            יבש     מנהרה    בהיר        תאורת מנהרה
# 336            יבש     מנהרה    בהיר        תאורת מנהרה
# 337            יבש     מנהרה    בהיר        תאורת מנהרה
# 338            יבש      צומת    בהיר  לילה + תאורת רחוב
#
#     lighting_condition_accident_severity      accident_type_severity  \
# 0                   תאורת מנהרה-נזק בלבד   חזית באחור - דרך-נזק בלבד
# 1                   תאורת מנהרה-נזק בלבד        איבוד שליטה-נזק בלבד
# 2                        תאורת מנהרה-קלה        חזית באחור - דרך-קלה
# 3                   תאורת מנהרה-נזק בלבד        איבוד שליטה-נזק בלבד
# 4                       אור יום-נזק בלבד  חזית באחור - צומת-נזק בלבד
# ..                                   ...                         ...
# 334                 תאורת מנהרה-נזק בלבד         חזית באחור-נזק בלבד
# 335                 תאורת מנהרה-נזק בלבד         חזית באחור-נזק בלבד
# 336                 תאורת מנהרה-נזק בלבד         חזית באחור-נזק בלבד
# 337                 תאורת מנהרה-נזק בלבד        איבוד שליטה-נזק בלבד
# 338           לילה + תאורת רחוב-נזק בלבד        איבוד שליטה-נזק בלבד
#
#     accident_type_severity_total_injuries                    event_number
# 0             חזית באחור - דרך-נזק בלבד-0                אירוע בגיב 44486
# 1                  איבוד שליטה-נזק בלבד-0  אירוע בגיב 106823 .תאונה עצמית
# 2                  חזית באחור - דרך-קלה-0               אירוע בגיב 164388
# 3                  איבוד שליטה-נזק בלבד-1  אירוע בגיב 183193 .תאונה עצמית
# 4            חזית באחור - צומת-נזק בלבד-0               אירוע בגיב 258664
# ..                                    ...                             ...
# 334                 חזית באחור-נזק בלבד-0                         1204381
# 335                 חזית באחור-נזק בלבד-0                         1204401
# 336                 חזית באחור-נזק בלבד-0                         1204405
# 337                איבוד שליטה-נזק בלבד-0                         1204407
# 338                איבוד שליטה-נזק בלבד-0                         1204411
#
# [339 rows x 34 columns]
